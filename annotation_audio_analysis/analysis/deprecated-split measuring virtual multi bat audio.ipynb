# %% [markdown]
# This notebook will perform the same split-measure analysis as done in a previous notebook (*'Split measuring all valid audio files.ipynb'*). The virtual multi bat audio files were generated by randomly adding 2-3 single bat audio files of a duration matched with that of an actual multi bat audio file. The virtual multi bat audio files were generated in another notebook (*../Making virtual multi bat audio .ipynb*).
#
# This notebook will continue and apply the same logic and workflow as the previous split-measure notebook. This maintains consistency. The consistency is especially required because the acoustic properties of the virtual multi bat audio will be compared with the acoustic properties of the observed multi bat audio.
#
# - Author: Thejasvi Beleyur
# - Date of initation: 2020-07-22

# %%
import glob
import datetime as dt
import sys
sys.path.append('/home/tbeleyur/Documents/packages_dev/correct_call_annotations/')
sys.path.append('../')
sys.path.append('../../individual_call_analysis/analysis/')

import correct_call_annotations.correct_call_annotations as cca
import format_and_clean
from format_and_clean import ind_call_format as icf
from measure_annot_audio import split_measure
from measure_annot_audio.inbuilt_measurement_functions import dB
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import soundfile as sf
import tqdm

# %%
# %matplotlib notebook

print(f'Notebook started at: {dt.datetime.now()}')
# Out:
# Notebook started at: 2020-09-25 13:58:31.501053

# %%
audio_source_folder = '../virtual_multi_bat_audio/'
virtual_multibat_to_measure = glob.glob(audio_source_folder + '*.WAV')
virtual_multibat_to_measure
# Out:
# ['../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_29_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_20_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_74_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_23_2_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_31_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_45_162_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_18_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_223_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_12_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_51_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_219_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_56_23_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-20_0200-0300_39_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-20_0200-0300_66_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_7_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_18_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_12_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_0120-0200_60_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_23_12_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_22_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_259_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_45_22_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_56_12_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_37_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_45_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_7_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_0120-0200_18_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_13_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_0120-0200_66_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_26_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_208_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_22_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_56_31_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-20_0200-0300_43_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_75_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_40_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_12_68_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_56_181_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_49_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_43_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_23_34_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_34_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_168_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_12_106_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_12_77_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_45_322_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_133_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_22_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_23_37_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_41_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_21_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_0120-0200_23_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_100_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-20_0200-0300_18_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_65_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_39_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_32_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_23_18_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_168_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_45_321_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_40_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_66_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_12_2_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_28_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_0120-0200_22_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_65_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_56_59_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_151_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_31_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_18_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_20_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_52_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_2_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_45_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_0120-0200_20_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_0120-0200_65_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_39_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_28_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_41_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_23_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_56_162_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_36_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_7_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_28_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_167_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_46_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_56_7_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_136_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_218_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_26_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_49_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_169_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_26_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_45_341_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_43_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_0120-0200_74_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_44_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_20_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_23_39_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-20_0300-0400_18_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_37_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_60_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_45_100_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_2_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_65_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_216_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_67_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_60_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_01_24_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_23_40_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_40_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_48_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_12_53_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_23_31_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-19_0120-0200_59_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_100_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_228_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_21502300_36_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_182_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-16_2324_59_hp_singlebatmixed.WAV',
#  '../virtual_multi_bat_audio/matching_annotaudio_Aditya_2018-08-17_34_133_hp_singlebatmixed.WAV']

# %%
all_measures = []

fs = 250000
kwargs = { 'inter_peak_difference':250, 
           'spectrum_smoothing_width': 100,
           'peak_range': 14,
           'fs':fs,
           'db_range':46,
           'overlap':0.5,
           'threshold':95,
           'nperseg':512,
           'fm_freqs_condition' : lambda X : X<98000,
           'non_signal_freqs_condition' : lambda X: X<70000
          
            }

for each in tqdm.tqdm(virtual_multibat_to_measure):

    measurements = split_measure.split_measure_audio(each,
                                  **kwargs)
    all_measures.append(measurements)
# Out:
#  26%|██▋       | 32/121 [00:19<00:40,  2.18it/s]../measure_annot_audio/inbuilt_measurement_functions.py:48: RuntimeWarning: divide by zero encountered in log10
#   power_spectrum_audio = 20*np.log10(np.abs(np.fft.rfft(audio)))
# 100%|██████████| 121/121 [01:14<00:00,  1.63it/s]

# %%
all_virtual_splitmeasure = pd.concat(all_measures).reset_index(drop=True)


all_virtual_splitmeasure['unique_window_id'] = all_virtual_splitmeasure['segment_number'].astype(str) +'_'+all_virtual_splitmeasure['file_name']

# %%
all_virtual_splitmeasure
# Out:
#                value  segment_number           measurement  \
# 0           0.032842               0                   rms
# 1           0.123779               0        peak_amplitude
# 2      104480.000000               0  dominant_frequencies
# 3       91308.593750               0     fm_terminal_freqs
# 4       96191.406250               0     fm_terminal_freqs
# ...              ...             ...                   ...
# 58787  109380.000000              91  dominant_frequencies
# 58788  109660.000000              91  dominant_frequencies
# 58789  109900.000000              91  dominant_frequencies
# 58790   87402.343750              91     fm_terminal_freqs
# 58791   88378.906250              91     fm_terminal_freqs
#
#                                                file_name  \
# 0      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 1      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 2      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 3      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 4      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# ...                                                  ...
# 58787  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 58788  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 58789  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 58790  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 58791  matching_annotaudio_Aditya_2018-08-17_34_133_h...
#
#                                         unique_window_id
# 0      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 1      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 2      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 3      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 4      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# ...                                                  ...
# 58787  91_matching_annotaudio_Aditya_2018-08-17_34_13...
# 58788  91_matching_annotaudio_Aditya_2018-08-17_34_13...
# 58789  91_matching_annotaudio_Aditya_2018-08-17_34_13...
# 58790  91_matching_annotaudio_Aditya_2018-08-17_34_13...
# 58791  91_matching_annotaudio_Aditya_2018-08-17_34_13...
#
# [58792 rows x 5 columns]

# %%
rms_values = all_virtual_splitmeasure[all_virtual_splitmeasure['measurement']=='rms']
plt.figure()
plt.boxplot(dB(rms_values['value']))
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9a30c1c550>,
#   <matplotlib.lines.Line2D at 0x7f9a30c1ca20>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f9a30c1c780>,
#   <matplotlib.lines.Line2D at 0x7f9a30c4c400>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9a30c1c390>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9a30c4c208>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9a30c4cf28>],
#  'means': []}

# %% [markdown]
# ### Choosing only the louder audio segments

# %%
plus20dB_threshold = pd.read_csv('../call_threshold_levels.csv')
plus20dB_threshold
# Out:
#    Unnamed: 0  call_dbpeak_threshold  call_dbrms_threshold
# 0           0                  -23.0                 -37.0

# %%
# function copied from the original split measure notebook

def choose_all_windows_above_threshold(measurement_df, threshold):
    '''
    Chooses all windows with rms greater or equal to the given rms threshold
    
    
    Parameters
    ----------
    measurement_df : pd.DataFrame
        A long dataframe with one measurement value per row
        Must have the columns 'measurement', 'unique_window_id'
        The 'measurement' column must also have some entries with 'rms' in them. 
    threshold : float>0
        The rms threshold to define windows which are not silent. 
    
    Returns 
    -------
    all_above_threshold : pd.DataFrame
        The dataframe with all segments across different files that are greater than or equal to the 
        chosen threshold rms. 
    '''

    rms_values = measurement_df[measurement_df['measurement']=='rms'].reset_index(drop=True)
    above_threshold = rms_values[rms_values['value']>=threshold]
    windowids_above_threshold = above_threshold['unique_window_id']
    all_above_threshold = measurement_df[measurement_df['unique_window_id'].isin(windowids_above_threshold)].reset_index(drop=True)
    return all_above_threshold

# %%
threshold_20db = float(10**(plus20dB_threshold['call_dbrms_threshold']/20.0))

# %%
non_silent_measures = choose_all_windows_above_threshold(all_virtual_splitmeasure, threshold_20db)

# %%
dom_freq = non_silent_measures[non_silent_measures['measurement']=='dominant_frequencies']


plt.figure()
plt.boxplot(dom_freq['value']);
plt.ylabel('Dominant frequencies, Hz')
plt.title('Data from virtual multibat audio segments +20 dB rms above silence')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Data from virtual multibat audio segments +20 dB rms above silence')

# %%
rms_df = non_silent_measures[non_silent_measures['measurement']=='rms']

plt.figure()
plt.boxplot(dB(rms_df['value']))
plt.ylabel('Audio segment level, dB rms')
plt.title('Data from virtual multibat audio segments +20 dB rms above silence')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Data from virtual multibat audio segments +20 dB rms above silence')

# %%
np.unique(non_silent_measures['measurement'])
# Out:
# array(['dominant_frequencies', 'fm_terminal_freqs', 'peak_amplitude',
#        'rms'], dtype=object)

# %%
non_silent_measures
# Out:
#                value  segment_number           measurement  \
# 0           0.032842               0                   rms
# 1           0.123779               0        peak_amplitude
# 2      104480.000000               0  dominant_frequencies
# 3       91308.593750               0     fm_terminal_freqs
# 4       96191.406250               0     fm_terminal_freqs
# ...              ...             ...                   ...
# 11215  109380.000000              91  dominant_frequencies
# 11216  109660.000000              91  dominant_frequencies
# 11217  109900.000000              91  dominant_frequencies
# 11218   87402.343750              91     fm_terminal_freqs
# 11219   88378.906250              91     fm_terminal_freqs
#
#                                                file_name  \
# 0      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 1      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 2      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 3      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 4      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# ...                                                  ...
# 11215  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 11216  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 11217  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 11218  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 11219  matching_annotaudio_Aditya_2018-08-17_34_133_h...
#
#                                         unique_window_id
# 0      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 1      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 2      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 3      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 4      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# ...                                                  ...
# 11215  91_matching_annotaudio_Aditya_2018-08-17_34_13...
# 11216  91_matching_annotaudio_Aditya_2018-08-17_34_13...
# 11217  91_matching_annotaudio_Aditya_2018-08-17_34_13...
# 11218  91_matching_annotaudio_Aditya_2018-08-17_34_13...
# 11219  91_matching_annotaudio_Aditya_2018-08-17_34_13...
#
# [11220 rows x 5 columns]

# %%
lower_df = non_silent_measures[non_silent_measures['measurement']=='fm_terminal_freqs']

plt.figure()
plt.boxplot(lower_df['value'].dropna())
plt.ylabel('Terminal Frequency of FM segments , Hz')
plt.title('Data from virtual multibat audio segments +20 dB rms above silence')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Data from virtual multibat audio segments +20 dB rms above silence')

# %%
lower_df
# Out:
#              value  segment_number        measurement  \
# 3      91308.59375               0  fm_terminal_freqs
# 4      96191.40625               0  fm_terminal_freqs
# 5      83984.37500               0  fm_terminal_freqs
# 6      85937.50000               0  fm_terminal_freqs
# 12     91308.59375               1  fm_terminal_freqs
# ...            ...             ...                ...
# 11203  95703.12500              88  fm_terminal_freqs
# 11208  88867.18750              89  fm_terminal_freqs
# 11212  88378.90625              90  fm_terminal_freqs
# 11218  87402.34375              91  fm_terminal_freqs
# 11219  88378.90625              91  fm_terminal_freqs
#
#                                                file_name  \
# 3      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 4      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 5      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 6      matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# 12     matching_annotaudio_Aditya_2018-08-17_01_29_hp...
# ...                                                  ...
# 11203  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 11208  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 11212  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 11218  matching_annotaudio_Aditya_2018-08-17_34_133_h...
# 11219  matching_annotaudio_Aditya_2018-08-17_34_133_h...
#
#                                         unique_window_id
# 3      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 4      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 5      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 6      0_matching_annotaudio_Aditya_2018-08-17_01_29_...
# 12     1_matching_annotaudio_Aditya_2018-08-17_01_29_...
# ...                                                  ...
# 11203  88_matching_annotaudio_Aditya_2018-08-17_34_13...
# 11208  89_matching_annotaudio_Aditya_2018-08-17_34_13...
# 11212  90_matching_annotaudio_Aditya_2018-08-17_34_13...
# 11218  91_matching_annotaudio_Aditya_2018-08-17_34_13...
# 11219  91_matching_annotaudio_Aditya_2018-08-17_34_13...
#
# [4176 rows x 5 columns]

# %%
dom_freq = non_silent_measures[non_silent_measures['measurement']=='dominant_frequencies']
minusx_df = non_silent_measures[non_silent_measures['measurement']=='fm_terminal_freqs']

plt.figure(figsize=(10,8))
a0 = plt.subplot(121)
plt.boxplot(dom_freq['value'].dropna())
plt.xlabel('Dominant frequencies')
plt.subplot(122, sharey=a0)
plt.boxplot(minusx_df['value'].dropna())
plt.xlabel('Terminal frequency of FM regions')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 0, 'Terminal frequency of FM regions')

# %%
non_silent_measures['video_annot_id'] = non_silent_measures['file_name'].str.lstrip('matching_annotaudio_')
# remove the '_hp' from the video_annot_ida

non_silent_measures['video_annot_id'] = non_silent_measures['video_annot_id'].str.rstrip('_hp_singlebatmixed.WAV')

# %%
video_annot_folder = '../../whole_data_analysis/annotations/corrected_HBC_video_annotations_Aditya/'
non_silent_measures['num_bats'] = icf.get_numbats_from_annotation_id(non_silent_measures['video_annot_id'], video_annot_folder)

# %%
group_size, counts = np.unique(non_silent_measures['num_bats'], return_counts=True)
print(group_size, counts)
# Out:
# [2 3] [9665 1555]

# %%
non_silent_measures.to_csv('non_silent_virtual_multibat_measurements_20dBthreshold.csv')

# %%
print(f'Notebook ended at: {dt.datetime.now()}')
# Out:
# Notebook ended at: 2020-09-25 14:00:01.585793
